# %% [markdown]
# <a href="https://colab.research.google.com/github/Riyanfebrisafputra/Riyan-Febri-Safputra/blob/main/TUGAS_10_RIYAN_FEBRI_SAFPUTRA_1101192462.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
from keras.models import Sequential
from keras.layers.core import Activation
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.optimizers import Adam
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
from PIL import Image
from imutils import paths
import numpy as np
import os
import cv2

# %%
print("[INFO] Loading Images ...")
image_paths = paths.list_images('3scene')
data = []
labels = []

for image_path in image_paths :
  image = Image.open(image_path)
  image = np.array(image.resize((64,64))) / 255.0
  data.append(image)
  
  label = image_path.split(os.path.sep)[-2]
  labels.append(label)
# Out:
# [INFO] Loading Images ...

# %%
lb = LabelBinarizer()
labels = lb.fit_transform(labels)
(trainX, testX, trainY, testY) = train_test_split(np.array(data), np.array(labels), test_size=0.25, shuffle=True)

# %%
model = Sequential(
    [
     Flatten(input_shape=(64*64*3,)),
     Dense(144, activation="relu", name="layer1"),
     Dense(24, activation="relu", name="layer2"),
     Dense(24, activation="relu", name="layer3"),
     Dense(24, activation="relu", name="layer4"),
     Dense(3, activation="softmax", name="layer5"),
    ]
)

# %%
print("[INFO] training network ...")
opt = Adam(lr=1e-3, decay=1e-3 / 50)
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
H = model.fit(trainX, trainY, validation_data=(testX, testY), epochs=65, batch_size=32)
# Out:
# [INFO] training network ...
# Epoch 1/65
# WARNING:tensorflow:Model was constructed with shape (None, 12288) for input Tensor("flatten_input:0", shape=(None, 12288), dtype=float32), but it was called on an input with incompatible shape (None, 64, 64, 3).
# WARNING:tensorflow:Model was constructed with shape (None, 12288) for input Tensor("flatten_input:0", shape=(None, 12288), dtype=float32), but it was called on an input with incompatible shape (None, 64, 64, 3).
# 21/23 [==========================>...] - ETA: 0s - loss: 1.2115 - accuracy: 0.3958WARNING:tensorflow:Model was constructed with shape (None, 12288) for input Tensor("flatten_input:0", shape=(None, 12288), dtype=float32), but it was called on an input with incompatible shape (None, 64, 64, 3).
# 23/23 [==============================] - 0s 21ms/step - loss: 1.1993 - accuracy: 0.3924 - val_loss: 1.1267 - val_accuracy: 0.5232
# Epoch 2/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.9727 - accuracy: 0.5246 - val_loss: 0.9065 - val_accuracy: 0.5401
# Epoch 3/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.8809 - accuracy: 0.5907 - val_loss: 0.9150 - val_accuracy: 0.5527
# Epoch 4/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.8202 - accuracy: 0.6315 - val_loss: 0.7772 - val_accuracy: 0.6878
# Epoch 5/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.7132 - accuracy: 0.7060 - val_loss: 0.8245 - val_accuracy: 0.6414
# Epoch 6/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.7328 - accuracy: 0.6850 - val_loss: 0.8050 - val_accuracy: 0.6287
# Epoch 7/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.6534 - accuracy: 0.7468 - val_loss: 0.7703 - val_accuracy: 0.6498
# Epoch 8/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.6510 - accuracy: 0.7131 - val_loss: 0.7244 - val_accuracy: 0.6835
# Epoch 9/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.5628 - accuracy: 0.7665 - val_loss: 0.6904 - val_accuracy: 0.7004
# Epoch 10/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.5645 - accuracy: 0.7750 - val_loss: 0.8870 - val_accuracy: 0.6245
# Epoch 11/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.6066 - accuracy: 0.7722 - val_loss: 0.6653 - val_accuracy: 0.7468
# Epoch 12/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.4744 - accuracy: 0.8186 - val_loss: 0.6273 - val_accuracy: 0.7595
# Epoch 13/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.4546 - accuracy: 0.8270 - val_loss: 0.6352 - val_accuracy: 0.7595
# Epoch 14/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.4836 - accuracy: 0.8158 - val_loss: 0.8330 - val_accuracy: 0.6540
# Epoch 15/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.5051 - accuracy: 0.8045 - val_loss: 0.6389 - val_accuracy: 0.7468
# Epoch 16/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.4493 - accuracy: 0.8383 - val_loss: 0.7194 - val_accuracy: 0.7046
# Epoch 17/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.3957 - accuracy: 0.8565 - val_loss: 0.8026 - val_accuracy: 0.7131
# Epoch 18/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.4428 - accuracy: 0.8242 - val_loss: 0.9173 - val_accuracy: 0.7046
# Epoch 19/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.4467 - accuracy: 0.8143 - val_loss: 0.6405 - val_accuracy: 0.7848
# Epoch 20/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.3514 - accuracy: 0.8805 - val_loss: 0.7084 - val_accuracy: 0.7468
# Epoch 21/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.3302 - accuracy: 0.8762 - val_loss: 0.5785 - val_accuracy: 0.8186
# Epoch 22/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.3465 - accuracy: 0.8594 - val_loss: 1.4007 - val_accuracy: 0.5696
# Epoch 23/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.4132 - accuracy: 0.8551 - val_loss: 0.6927 - val_accuracy: 0.7806
# Epoch 24/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.3231 - accuracy: 0.8762 - val_loss: 0.7037 - val_accuracy: 0.7637
# Epoch 25/65
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3031 - accuracy: 0.8917 - val_loss: 0.5992 - val_accuracy: 0.7848
# Epoch 26/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.3849 - accuracy: 0.8565 - val_loss: 0.5936 - val_accuracy: 0.8059
# Epoch 27/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2746 - accuracy: 0.9072 - val_loss: 0.6091 - val_accuracy: 0.8228
# Epoch 28/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2877 - accuracy: 0.8889 - val_loss: 0.5927 - val_accuracy: 0.8059
# Epoch 29/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2342 - accuracy: 0.9283 - val_loss: 0.6209 - val_accuracy: 0.7975
# Epoch 30/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2438 - accuracy: 0.9142 - val_loss: 0.6880 - val_accuracy: 0.7848
# Epoch 31/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2456 - accuracy: 0.9114 - val_loss: 0.7984 - val_accuracy: 0.7300
# Epoch 32/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.2892 - accuracy: 0.9015 - val_loss: 0.7674 - val_accuracy: 0.7342
# Epoch 33/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2265 - accuracy: 0.9241 - val_loss: 0.6525 - val_accuracy: 0.7722
# Epoch 34/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2207 - accuracy: 0.9212 - val_loss: 0.6251 - val_accuracy: 0.8186
# Epoch 35/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2443 - accuracy: 0.9015 - val_loss: 0.7911 - val_accuracy: 0.7511
# Epoch 36/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.3156 - accuracy: 0.8833 - val_loss: 0.7481 - val_accuracy: 0.7722
# Epoch 37/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.3387 - accuracy: 0.8790 - val_loss: 0.7033 - val_accuracy: 0.7722
# Epoch 38/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2385 - accuracy: 0.9184 - val_loss: 0.6084 - val_accuracy: 0.8270
# Epoch 39/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.2561 - accuracy: 0.8987 - val_loss: 0.6012 - val_accuracy: 0.8101
# Epoch 40/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2251 - accuracy: 0.9325 - val_loss: 0.7867 - val_accuracy: 0.7679
# Epoch 41/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2916 - accuracy: 0.8959 - val_loss: 0.6945 - val_accuracy: 0.8270
# Epoch 42/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2335 - accuracy: 0.9015 - val_loss: 0.6338 - val_accuracy: 0.8101
# Epoch 43/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1580 - accuracy: 0.9480 - val_loss: 0.7361 - val_accuracy: 0.7722
# Epoch 44/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1877 - accuracy: 0.9395 - val_loss: 0.6479 - val_accuracy: 0.8143
# Epoch 45/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1366 - accuracy: 0.9662 - val_loss: 0.6502 - val_accuracy: 0.8059
# Epoch 46/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1270 - accuracy: 0.9648 - val_loss: 0.6967 - val_accuracy: 0.7975
# Epoch 47/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1255 - accuracy: 0.9592 - val_loss: 0.7917 - val_accuracy: 0.7806
# Epoch 48/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1468 - accuracy: 0.9494 - val_loss: 0.7268 - val_accuracy: 0.8017
# Epoch 49/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1781 - accuracy: 0.9367 - val_loss: 0.6551 - val_accuracy: 0.8101
# Epoch 50/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1188 - accuracy: 0.9592 - val_loss: 0.7439 - val_accuracy: 0.7848
# Epoch 51/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1128 - accuracy: 0.9606 - val_loss: 0.6745 - val_accuracy: 0.8312
# Epoch 52/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.0999 - accuracy: 0.9691 - val_loss: 0.7364 - val_accuracy: 0.8186
# Epoch 53/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0959 - accuracy: 0.9761 - val_loss: 0.7748 - val_accuracy: 0.8101
# Epoch 54/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0941 - accuracy: 0.9662 - val_loss: 0.7814 - val_accuracy: 0.8312
# Epoch 55/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.1483 - accuracy: 0.9409 - val_loss: 0.9198 - val_accuracy: 0.7890
# Epoch 56/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2490 - accuracy: 0.9156 - val_loss: 0.8505 - val_accuracy: 0.7764
# Epoch 57/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2340 - accuracy: 0.9086 - val_loss: 1.0063 - val_accuracy: 0.7300
# Epoch 58/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.1778 - accuracy: 0.9269 - val_loss: 0.9863 - val_accuracy: 0.7426
# Epoch 59/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1599 - accuracy: 0.9395 - val_loss: 0.7424 - val_accuracy: 0.8059
# Epoch 60/65
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0904 - accuracy: 0.9733 - val_loss: 0.7834 - val_accuracy: 0.8186
# Epoch 61/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0718 - accuracy: 0.9789 - val_loss: 0.9316 - val_accuracy: 0.7890
# Epoch 62/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0823 - accuracy: 0.9733 - val_loss: 0.8228 - val_accuracy: 0.7975
# Epoch 63/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0646 - accuracy: 0.9859 - val_loss: 0.8071 - val_accuracy: 0.8270
# Epoch 64/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.0926 - accuracy: 0.9578 - val_loss: 0.8653 - val_accuracy: 0.7975
# Epoch 65/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0556 - accuracy: 0.9873 - val_loss: 0.8029 - val_accuracy: 0.8143

# %%
plt.plot(H.history['accuracy'])
plt.plot(H.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(H.history['loss'])
plt.plot(H.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
print("[INFO] evaluating network ...")
predictions = model.predict(testX, batch_size=32)
print(classification_report(testY.argmax(axis=1), predictions.argmax(axis=1), target_names=lb.classes_))
# Out:
# [INFO] evaluating network ...
# WARNING:tensorflow:Model was constructed with shape (None, 12288) for input Tensor("flatten_input:0", shape=(None, 12288), dtype=float32), but it was called on an input with incompatible shape (None, 64, 64, 3).
#               precision    recall  f1-score   support
#
#        coast       0.81      0.85      0.83        95
#       forest       0.86      0.82      0.84        79
#      highway       0.77      0.75      0.76        63
#
#     accuracy                           0.81       237
#    macro avg       0.81      0.81      0.81       237
# weighted avg       0.81      0.81      0.81       237

# %%
model.save('nnmodel_scene')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: nnmodel_scene/assets

# %%
images = ['forest_test.jpg', 'coast_test.jpg']
for i in range(2) :
  img_array = cv2.imread(images[i])
  img_array = cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB)
  plt.imshow(img_array)
  plt.show()
  image_test = Image.open(images[i])
  image_test = np.array(image_test.resize((64,64))) /255.0
  image_test = np.expand_dims(image_test, axis=0)
  output = model.predict(image_test, 1)
  print(output)
  print(lb.classes_[output.argmax(axis=1)])
# Out:
# [[0.00408389 0.9945205  0.00139569]]
# ['forest']
# [[0.92347085 0.06498442 0.01154471]]
# ['coast']
